# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pygenesis.table import get_tablefile_data
# Out:
# Error while loading the config file. Could not find C:\Users\micha\AppData\Local\Temp\pytest-of-micha\pytest-78\.pygenesis3\config.ini. Please make sure to run init_config() first.

# %% [markdown]
# ## Download a table(file)

# %% [markdown]
# The `get_tablefile_data()` function will download the tablefile as (flat)csv and return the data as pandas DataFrame.

# %%
data = get_tablefile_data("61111-0002", table_area=all)

# %%
type(data), len(data)
# Out:
# (pandas.core.frame.DataFrame, 20)

# %%
data
# Out:
#     Statistik_Code                        Statistik_Label Zeit_Code  \
# 0            61111  Verbraucherpreisindex für Deutschland      JAHR
# 1            61111  Verbraucherpreisindex für Deutschland      JAHR
# 2            61111  Verbraucherpreisindex für Deutschland      JAHR
# 3            61111  Verbraucherpreisindex für Deutschland      JAHR
# 4            61111  Verbraucherpreisindex für Deutschland      JAHR
# 5            61111  Verbraucherpreisindex für Deutschland      JAHR
# 6            61111  Verbraucherpreisindex für Deutschland      JAHR
# 7            61111  Verbraucherpreisindex für Deutschland      JAHR
# 8            61111  Verbraucherpreisindex für Deutschland      JAHR
# 9            61111  Verbraucherpreisindex für Deutschland      JAHR
# 10           61111  Verbraucherpreisindex für Deutschland      JAHR
# 11           61111  Verbraucherpreisindex für Deutschland      JAHR
# 12           61111  Verbraucherpreisindex für Deutschland      JAHR
# 13           61111  Verbraucherpreisindex für Deutschland      JAHR
# 14           61111  Verbraucherpreisindex für Deutschland      JAHR
# 15           61111  Verbraucherpreisindex für Deutschland      JAHR
# 16           61111  Verbraucherpreisindex für Deutschland      JAHR
# 17           61111  Verbraucherpreisindex für Deutschland      JAHR
# 18           61111  Verbraucherpreisindex für Deutschland      JAHR
# 19           61111  Verbraucherpreisindex für Deutschland      JAHR
#
#    Zeit_Label  Zeit 1_Merkmal_Code        1_Merkmal_Label 1_Auspraegung_Code  \
# 0        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 1        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 2        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 3        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 4        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 5        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 6        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 7        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 8        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 9        Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 10       Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 11       Jahr  2021          DINSG  Deutschland insgesamt                 DG
# 12       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 13       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 14       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 15       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 16       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 17       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 18       Jahr  2022          DINSG  Deutschland insgesamt                 DG
# 19       Jahr  2022          DINSG  Deutschland insgesamt                 DG
#
#    1_Auspraegung_Label 2_Merkmal_Code 2_Merkmal_Label 2_Auspraegung_Code  \
# 0          Deutschland          MONAT          Monate            MONAT01
# 1          Deutschland          MONAT          Monate            MONAT02
# 2          Deutschland          MONAT          Monate            MONAT03
# 3          Deutschland          MONAT          Monate            MONAT04
# 4          Deutschland          MONAT          Monate            MONAT05
# 5          Deutschland          MONAT          Monate            MONAT06
# 6          Deutschland          MONAT          Monate            MONAT07
# 7          Deutschland          MONAT          Monate            MONAT08
# 8          Deutschland          MONAT          Monate            MONAT09
# 9          Deutschland          MONAT          Monate            MONAT10
# 10         Deutschland          MONAT          Monate            MONAT11
# 11         Deutschland          MONAT          Monate            MONAT12
# 12         Deutschland          MONAT          Monate            MONAT01
# 13         Deutschland          MONAT          Monate            MONAT02
# 14         Deutschland          MONAT          Monate            MONAT03
# 15         Deutschland          MONAT          Monate            MONAT04
# 16         Deutschland          MONAT          Monate            MONAT05
# 17         Deutschland          MONAT          Monate            MONAT06
# 18         Deutschland          MONAT          Monate            MONAT07
# 19         Deutschland          MONAT          Monate            MONAT08
#
#    2_Auspraegung_Label PREIS1__Verbraucherpreisindex__2015=100  \
# 0               Januar                                   106,3
# 1              Februar                                   107,0
# 2                 März                                   107,5
# 3                April                                   108,2
# 4                  Mai                                   108,7
# 5                 Juni                                   109,1
# 6                 Juli                                   110,1
# 7               August                                   110,1
# 8            September                                   110,1
# 9              Oktober                                   110,7
# 10            November                                   110,5
# 11            Dezember                                   111,1
# 12              Januar                                   111,5
# 13             Februar                                   112,5
# 14                März                                   115,3
# 15               April                                   116,2
# 16                 Mai                                   117,3
# 17                Juni                                   117,4
# 18                Juli                                     ...
# 19              August                                     ...
#
#    CH0004__Veraenderung_zum_Vorjahresmonat__in_(%)  \
# 0                                             +1,0
# 1                                             +1,3
# 2                                             +1,7
# 3                                             +2,0
# 4                                             +2,5
# 5                                             +2,3
# 6                                             +3,8
# 7                                             +3,9
# 8                                             +4,1
# 9                                             +4,5
# 10                                            +5,2
# 11                                            +5,3
# 12                                            +4,9
# 13                                            +5,1
# 14                                            +7,3
# 15                                            +7,4
# 16                                            +7,9
# 17                                            +7,6
# 18                                             ...
# 19                                             ...
#
#    CH0005__Veraenderung_zum_Vormonat__in_(%)
# 0                                       +0,8
# 1                                       +0,7
# 2                                       +0,5
# 3                                       +0,7
# 4                                       +0,5
# 5                                       +0,4
# 6                                       +0,9
# 7                                          -
# 8                                          -
# 9                                       +0,5
# 10                                      -0,2
# 11                                      +0,5
# 12                                      +0,4
# 13                                      +0,9
# 14                                      +2,5
# 15                                      +0,8
# 16                                      +0,9
# 17                                      +0,1
# 18                                       ...
# 19                                       ...
